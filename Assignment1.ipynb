# %%
#TOPIC - LIST
#1. 
numbers=[22,31,44,12,56]
print(numbers)
# Out:
# [22, 31, 44, 12, 56]

# %%
# 2.
numbers.append(39)
numbers.append(42)
numbers.append(27)
print(numbers)
# Out:
# [22, 31, 44, 12, 56, 39, 42, 27]

# %%
#3
for number in numbers:
    print(number)
# Out:
# 22
# 31
# 44
# 12
# 56
# 39
# 42
# 27

# %%
# DICTIONARY
#1.
person={"name":"John","age":25,"address":"New York"}
print(person)
# Out:
# {'name': 'John', 'age': 25, 'address': 'New York'}

# %%
#2.
person["phone"]='1234567890'
print(person)
# Out:
# {'name': 'John', 'age': 25, 'address': 'New York', 'phone': '1234567890'}

# %%
#SET
#1.
set1={1,2,3,4,5}
print(set1)
# Out:
# {1, 2, 3, 4, 5}

# %%
#2.
set1.add(6)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#3.
set1.remove(3)
print(set1)
# Out:
# {1, 2, 4, 5, 6}

# %%
#TUPLE
#1.
values=(1,2,3,4)
print(values)
# Out:
# (1, 2, 3, 4)

# %%
#2.
print(len(values))
# Out:
# 4
